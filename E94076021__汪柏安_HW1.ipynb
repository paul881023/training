# %%
from apyori import apriori
import pandas as pd
#輸入檔案
data = pd.read_csv('Apriori_set.csv')
#設定apriori運算
assoiciation_rules = apriori(data, min_support=0.4, min_confidence=0.8)
#列出強關聯原則
association_results = list(assoiciation_rules)
for item in association_results:
    li_item = list(item)
    for i in li_item[2]:
        a = list(i)
        print('items_base',list((a[0])))
        print('items_add',list((a[1])))
        print('confidence', a[2])
        print('lift:',a[3])
    print('support',li_item[1])
    print('-----')
# Out:
# items_base []
# items_add ['i']
# confidence 1.0
# lift: 1.0
# support 1.0
# -----
# items_base ['d']
# items_add ['i']
# confidence 1.0
# lift: 1.0
# support 0.5
# -----
# items_base ['e']
# items_add ['i']
# confidence 1.0
# lift: 1.0
# support 0.5
# -----
# items_base ['e']
# items_add ['m']
# confidence 1.0
# lift: 2.0
# items_base ['m']
# items_add ['e']
# confidence 1.0
# lift: 2.0
# support 0.5
# -----
# items_base ['e']
# items_add ['s']
# confidence 1.0
# lift: 2.0
# items_base ['s']
# items_add ['e']
# confidence 1.0
# lift: 2.0
# support 0.5
# -----
# items_base ['e']
# items_add ['t']
# confidence 1.0
# lift: 2.0
# items_base ['t']
# items_add ['e']
# confidence 1.0
# lift: 2.0
# support 0.5
# -----
# items_base ['m']
# items_add ['i']
# confidence 1.0
# lift: 1.0
# support 0.5
# -----
# items_base ['s']
# items_add ['i']
# confidence 1.0
# lift: 1.0
# support 0.5
# -----
# items_base ['t']
# items_add ['i']
# confidence 1.0
# lift: 1.0
# support 0.5
# -----
# items_base ['m']
# items_add ['s']
# confidence 1.0
# lift: 2.0
# items_base ['s']
# items_add ['m']
# confidence 1.0
# lift: 2.0
# support 0.5
# -----
# items_base ['m']
# items_add ['t']
# confidence 1.0
# lift: 2.0
# items_base ['t']
# items_add ['m']
# confidence 1.0
# lift: 2.0
# support 0.5
# -----
# items_base ['s']
# items_add ['t']
# confidence 1.0
# lift: 2.0
# items_base ['t']
# items_add ['s']
# confidence 1.0
# lift: 2.0
# support 0.5
# -----
# items_base ['e']
# items_add ['i', 'm']
# confidence 1.0
# lift: 2.0
# items_base ['m']
# items_add ['i', 'e']
# confidence 1.0
# lift: 2.0
# items_base ['i', 'e']
# items_add ['m']
# confidence 1.0
# lift: 2.0
# items_base ['e', 'm']
# items_add ['i']
# confidence 1.0
# lift: 1.0
# items_base ['i', 'm']
# items_add ['e']
# confidence 1.0
# lift: 2.0
# support 0.5
# -----
# items_base ['e']
# items_add ['i', 's']
# confidence 1.0
# lift: 2.0
# items_base ['s']
# items_add ['i', 'e']
# confidence 1.0
# lift: 2.0
# items_base ['i', 'e']
# items_add ['s']
# confidence 1.0
# lift: 2.0
# items_base ['e', 's']
# items_add ['i']
# confidence 1.0
# lift: 1.0
# items_base ['i', 's']
# items_add ['e']
# confidence 1.0
# lift: 2.0
# support 0.5
# -----
# items_base ['e']
# items_add ['i', 't']
# confidence 1.0
# lift: 2.0
# items_base ['t']
# items_add ['i', 'e']
# confidence 1.0
# lift: 2.0
# items_base ['i', 'e']
# items_add ['t']
# confidence 1.0
# lift: 2.0
# items_base ['e', 't']
# items_add ['i']
# confidence 1.0
# lift: 1.0
# items_base ['i', 't']
# items_add ['e']
# confidence 1.0
# lift: 2.0
# support 0.5
# -----
# items_base ['e']
# items_add ['m', 's']
# confidence 1.0
# lift: 2.0
# items_base ['m']
# items_add ['e', 's']
# confidence 1.0
# lift: 2.0
# items_base ['s']
# items_add ['e', 'm']
# confidence 1.0
# lift: 2.0
# items_base ['e', 'm']
# items_add ['s']
# confidence 1.0
# lift: 2.0
# items_base ['e', 's']
# items_add ['m']
# confidence 1.0
# lift: 2.0
# items_base ['m', 's']
# items_add ['e']
# confidence 1.0
# lift: 2.0
# support 0.5
# -----
# items_base ['e']
# items_add ['m', 't']
# confidence 1.0
# lift: 2.0
# items_base ['m']
# items_add ['e', 't']
# confidence 1.0
# lift: 2.0
# items_base ['t']
# items_add ['e', 'm']
# confidence 1.0
# lift: 2.0
# items_base ['e', 'm']
# items_add ['t']
# confidence 1.0
# lift: 2.0
# items_base ['e', 't']
# items_add ['m']
# confidence 1.0
# lift: 2.0
# items_base ['m', 't']
# items_add ['e']
# confidence 1.0
# lift: 2.0
# support 0.5
# -----
# items_base ['e']
# items_add ['s', 't']
# confidence 1.0
# lift: 2.0
# items_base ['s']
# items_add ['e', 't']
# confidence 1.0
# lift: 2.0
# items_base ['t']
# items_add ['e', 's']
# confidence 1.0
# lift: 2.0
# items_base ['e', 's']
# items_add ['t']
# confidence 1.0
# lift: 2.0
# items_base ['e', 't']
# items_add ['s']
# confidence 1.0
# lift: 2.0
# items_base ['s', 't']
# items_add ['e']
# confidence 1.0
# lift: 2.0
# support 0.5
# -----
# items_base ['m']
# items_add ['i', 's']
# confidence 1.0
# lift: 2.0
# items_base ['s']
# items_add ['i', 'm']
# confidence 1.0
# lift: 2.0
# items_base ['i', 'm']
# items_add ['s']
# confidence 1.0
# lift: 2.0
# items_base ['i', 's']
# items_add ['m']
# confidence 1.0
# lift: 2.0
# items_base ['m', 's']
# items_add ['i']
# confidence 1.0
# lift: 1.0
# support 0.5
# -----
# items_base ['m']
# items_add ['i', 't']
# confidence 1.0
# lift: 2.0
# items_base ['t']
# items_add ['i', 'm']
# confidence 1.0
# lift: 2.0
# items_base ['i', 'm']
# items_add ['t']
# confidence 1.0
# lift: 2.0
# items_base ['i', 't']
# items_add ['m']
# confidence 1.0
# lift: 2.0
# items_base ['m', 't']
# items_add ['i']
# confidence 1.0
# lift: 1.0
# support 0.5
# -----
# items_base ['s']
# items_add ['i', 't']
# confidence 1.0
# lift: 2.0
# items_base ['t']
# items_add ['i', 's']
# confidence 1.0
# lift: 2.0
# items_base ['i', 's']
# items_add ['t']
# confidence 1.0
# lift: 2.0
# items_base ['i', 't']
# items_add ['s']
# confidence 1.0
# lift: 2.0
# items_base ['s', 't']
# items_add ['i']
# confidence 1.0
# lift: 1.0
# support 0.5
# -----
# items_base ['m']
# items_add ['s', 't']
# confidence 1.0
# lift: 2.0
# items_base ['s']
# items_add ['m', 't']
# confidence 1.0
# lift: 2.0
# items_base ['t']
# items_add ['m', 's']
# confidence 1.0
# lift: 2.0
# items_base ['m', 's']
# items_add ['t']
# confidence 1.0
# lift: 2.0
# items_base ['m', 't']
# items_add ['s']
# confidence 1.0
# lift: 2.0
# items_base ['s', 't']
# items_add ['m']
# confidence 1.0
# lift: 2.0
# support 0.5
# -----
# items_base ['e']
# items_add ['i', 'm', 's']
# confidence 1.0
# lift: 2.0
# items_base ['m']
# items_add ['i', 'e', 's']
# confidence 1.0
# lift: 2.0
# items_base ['s']
# items_add ['i', 'e', 'm']
# confidence 1.0
# lift: 2.0
# items_base ['i', 'e']
# items_add ['m', 's']
# confidence 1.0
# lift: 2.0
# items_base ['e', 'm']
# items_add ['i', 's']
# confidence 1.0
# lift: 2.0
# items_base ['e', 's']
# items_add ['i', 'm']
# confidence 1.0
# lift: 2.0
# items_base ['i', 'm']
# items_add ['e', 's']
# confidence 1.0
# lift: 2.0
# items_base ['i', 's']
# items_add ['e', 'm']
# confidence 1.0
# lift: 2.0
# items_base ['m', 's']
# items_add ['i', 'e']
# confidence 1.0
# lift: 2.0
# items_base ['i', 'e', 'm']
# items_add ['s']
# confidence 1.0
# lift: 2.0
# items_base ['i', 'e', 's']
# items_add ['m']
# confidence 1.0
# lift: 2.0
# items_base ['e', 'm', 's']
# items_add ['i']
# confidence 1.0
# lift: 1.0
# items_base ['i', 'm', 's']
# items_add ['e']
# confidence 1.0
# lift: 2.0
# support 0.5
# -----
# items_base ['e']
# items_add ['i', 'm', 't']
# confidence 1.0
# lift: 2.0
# items_base ['m']
# items_add ['i', 'e', 't']
# confidence 1.0
# lift: 2.0
# items_base ['t']
# items_add ['i', 'e', 'm']
# confidence 1.0
# lift: 2.0
# items_base ['i', 'e']
# items_add ['m', 't']
# confidence 1.0
# lift: 2.0
# items_base ['e', 'm']
# items_add ['i', 't']
# confidence 1.0
# lift: 2.0
# items_base ['e', 't']
# items_add ['i', 'm']
# confidence 1.0
# lift: 2.0
# items_base ['i', 'm']
# items_add ['e', 't']
# confidence 1.0
# lift: 2.0
# items_base ['i', 't']
# items_add ['e', 'm']
# confidence 1.0
# lift: 2.0
# items_base ['m', 't']
# items_add ['i', 'e']
# confidence 1.0
# lift: 2.0
# items_base ['i', 'e', 'm']
# items_add ['t']
# confidence 1.0
# lift: 2.0
# items_base ['i', 'e', 't']
# items_add ['m']
# confidence 1.0
# lift: 2.0
# items_base ['e', 'm', 't']
# items_add ['i']
# confidence 1.0
# lift: 1.0
# items_base ['i', 'm', 't']
# items_add ['e']
# confidence 1.0
# lift: 2.0
# support 0.5
# -----
# items_base ['e']
# items_add ['i', 's', 't']
# confidence 1.0
# lift: 2.0
# items_base ['s']
# items_add ['i', 'e', 't']
# confidence 1.0
# lift: 2.0
# items_base ['t']
# items_add ['i', 'e', 's']
# confidence 1.0
# lift: 2.0
# items_base ['i', 'e']
# items_add ['s', 't']
# confidence 1.0
# lift: 2.0
# items_base ['e', 's']
# items_add ['i', 't']
# confidence 1.0
# lift: 2.0
# items_base ['e', 't']
# items_add ['i', 's']
# confidence 1.0
# lift: 2.0
# items_base ['i', 's']
# items_add ['e', 't']
# confidence 1.0
# lift: 2.0
# items_base ['i', 't']
# items_add ['e', 's']
# confidence 1.0
# lift: 2.0
# items_base ['s', 't']
# items_add ['i', 'e']
# confidence 1.0
# lift: 2.0
# items_base ['i', 'e', 's']
# items_add ['t']
# confidence 1.0
# lift: 2.0
# items_base ['i', 'e', 't']
# items_add ['s']
# confidence 1.0
# lift: 2.0
# items_base ['e', 's', 't']
# items_add ['i']
# confidence 1.0
# lift: 1.0
# items_base ['i', 's', 't']
# items_add ['e']
# confidence 1.0
# lift: 2.0
# support 0.5
# -----
# items_base ['e']
# items_add ['m', 's', 't']
# confidence 1.0
# lift: 2.0
# items_base ['m']
# items_add ['e', 's', 't']
# confidence 1.0
# lift: 2.0
# items_base ['s']
# items_add ['e', 'm', 't']
# confidence 1.0
# lift: 2.0
# items_base ['t']
# items_add ['e', 'm', 's']
# confidence 1.0
# lift: 2.0
# items_base ['e', 'm']
# items_add ['s', 't']
# confidence 1.0
# lift: 2.0
# items_base ['e', 's']
# items_add ['m', 't']
# confidence 1.0
# lift: 2.0
# items_base ['e', 't']
# items_add ['m', 's']
# confidence 1.0
# lift: 2.0
# items_base ['m', 's']
# items_add ['e', 't']
# confidence 1.0
# lift: 2.0
# items_base ['m', 't']
# items_add ['e', 's']
# confidence 1.0
# lift: 2.0
# items_base ['s', 't']
# items_add ['e', 'm']
# confidence 1.0
# lift: 2.0
# items_base ['e', 'm', 's']
# items_add ['t']
# confidence 1.0
# lift: 2.0
# items_base ['e', 'm', 't']
# items_add ['s']
# confidence 1.0
# lift: 2.0
# items_base ['e', 's', 't']
# items_add ['m']
# confidence 1.0
# lift: 2.0
# items_base ['m', 's', 't']
# items_add ['e']
# confidence 1.0
# lift: 2.0
# support 0.5
# -----
# items_base ['m']
# items_add ['i', 's', 't']
# confidence 1.0
# lift: 2.0
# items_base ['s']
# items_add ['i', 'm', 't']
# confidence 1.0
# lift: 2.0
# items_base ['t']
# items_add ['i', 'm', 's']
# confidence 1.0
# lift: 2.0
# items_base ['i', 'm']
# items_add ['s', 't']
# confidence 1.0
# lift: 2.0
# items_base ['i', 's']
# items_add ['m', 't']
# confidence 1.0
# lift: 2.0
# items_base ['i', 't']
# items_add ['m', 's']
# confidence 1.0
# lift: 2.0
# items_base ['m', 's']
# items_add ['i', 't']
# confidence 1.0
# lift: 2.0
# items_base ['m', 't']
# items_add ['i', 's']
# confidence 1.0
# lift: 2.0
# items_base ['s', 't']
# items_add ['i', 'm']
# confidence 1.0
# lift: 2.0
# items_base ['i', 'm', 's']
# items_add ['t']
# confidence 1.0
# lift: 2.0
# items_base ['i', 'm', 't']
# items_add ['s']
# confidence 1.0
# lift: 2.0
# items_base ['i', 's', 't']
# items_add ['m']
# confidence 1.0
# lift: 2.0
# items_base ['m', 's', 't']
# items_add ['i']
# confidence 1.0
# lift: 1.0
# support 0.5
# -----
# items_base ['e']
# items_add ['i', 's', 'm', 't']
# confidence 1.0
# lift: 2.0
# items_base ['m']
# items_add ['i', 'e', 's', 't']
# confidence 1.0
# lift: 2.0
# items_base ['s']
# items_add ['i', 'e', 'm', 't']
# confidence 1.0
# lift: 2.0
# items_base ['t']
# items_add ['i', 'e', 'm', 's']
# confidence 1.0
# lift: 2.0
# items_base ['i', 'e']
# items_add ['s', 'm', 't']
# confidence 1.0
# lift: 2.0
# items_base ['e', 'm']
# items_add ['i', 's', 't']
# confidence 1.0
# lift: 2.0
# items_base ['e', 's']
# items_add ['i', 'm', 't']
# confidence 1.0
# lift: 2.0
# items_base ['e', 't']
# items_add ['i', 'm', 's']
# confidence 1.0
# lift: 2.0
# items_base ['i', 'm']
# items_add ['s', 'e', 't']
# confidence 1.0
# lift: 2.0
# items_base ['i', 's']
# items_add ['e', 'm', 't']
# confidence 1.0
# lift: 2.0
# items_base ['i', 't']
# items_add ['e', 'm', 's']
# confidence 1.0
# lift: 2.0
# items_base ['m', 's']
# items_add ['i', 'e', 't']
# confidence 1.0
# lift: 2.0
# items_base ['m', 't']
# items_add ['i', 'e', 's']
# confidence 1.0
# lift: 2.0
# items_base ['s', 't']
# items_add ['i', 'e', 'm']
# confidence 1.0
# lift: 2.0
# items_base ['i', 'e', 'm']
# items_add ['s', 't']
# confidence 1.0
# lift: 2.0
# items_base ['i', 'e', 's']
# items_add ['m', 't']
# confidence 1.0
# lift: 2.0
# items_base ['i', 'e', 't']
# items_add ['m', 's']
# confidence 1.0
# lift: 2.0
# items_base ['e', 'm', 's']
# items_add ['i', 't']
# confidence 1.0
# lift: 2.0
# items_base ['e', 'm', 't']
# items_add ['i', 's']
# confidence 1.0
# lift: 2.0
# items_base ['e', 's', 't']
# items_add ['i', 'm']
# confidence 1.0
# lift: 2.0
# items_base ['i', 'm', 's']
# items_add ['e', 't']
# confidence 1.0
# lift: 2.0
# items_base ['i', 'm', 't']
# items_add ['e', 's']
# confidence 1.0
# lift: 2.0
# items_base ['i', 's', 't']
# items_add ['e', 'm']
# confidence 1.0
# lift: 2.0
# items_base ['m', 's', 't']
# items_add ['i', 'e']
# confidence 1.0
# lift: 2.0
# items_base ['i', 'e', 'm', 's']
# items_add ['t']
# confidence 1.0
# lift: 2.0
# items_base ['i', 'e', 'm', 't']
# items_add ['s']
# confidence 1.0
# lift: 2.0
# items_base ['i', 'e', 's', 't']
# items_add ['m']
# confidence 1.0
# lift: 2.0
# items_base ['e', 'm', 's', 't']
# items_add ['i']
# confidence 1.0
# lift: 1.0
# items_base ['i', 'm', 's', 't']
# items_add ['e']
# confidence 1.0
# lift: 2.0
# support 0.5
# -----
